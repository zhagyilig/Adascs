# %%
from pyzabbix import ZabbixAPI

zapi = ZabbixAPI("https://op.ezbuy.me/zabbix")
zapi.login("zhangyiling", "88888888")
print("Connected to Zabbix API Version %s" % zapi.api_version())

host_list = []
hostid_list = []
for h in zapi.host.get(output="extend"):
    host = h['host']
    if host.startswith('lsg') is True:
        hostid_list.append(h['hostid'])
        print(h['hostid'])
print(len(hostid_list))
        
#     print(h['host'])
#     host = h['hostid']
#     print(host)
#     host_list.append(host)
# print(len(host_list))

# for n in host_list:
#     if n.startswith('lsg') is True:
#         print(n['hostid'])
# Out:
# Connected to Zabbix API Version 4.0.4
# 10718
# 10719
# 10720
# 10721
# 10722
# 10723
# 10724
# 10725
# 10726
# 10729
# 10730
# 10731
# 10732
# 10734
# 10735
# 10738
# 10739
# 10740
# 10741
# 10742
# 10743
# 10744
# 10745
# 10746
# 10747
# 10748
# 10749
# 10750
# 10751
# 10752
# 10753
# 10754
# 10755
# 10757
# 10758
# 10759
# 10775
# 10776
# 10777
# 10778
# 10779
# 10780
# 10781
# 10782
# 10783
# 10784
# 10785
# 10786
# 10787
# 10788
# 10789
# 10790
# 10799
# 10800
# 10801
# 10802
# 10803
# 10804
# 10805
# 10806
# 10807
# 10808
# 10809
# 10810
# 10811
# 10812
# 10813
# 10814
# 10815
# 10816
# 10817
# 10818
# 10819
# 10820
# 10821
# 10822
# 10823
# 10824
# 10825
# 10826
# 10827
# 10828
# 10832
# 10833
# 10834
# 10835
# 10836
# 10837
# 10838
# 10839
# 10841
# 10842
# 10843
# 10844
# 10845
# 10846
# 10847
# 10848
# 10849
# 10850
# 10851
# 10852
# 102

# %%
[n for n in dir(zapi) if n.startswith("_") is False]
# Out:
# ['api_version',
#  'auth',
#  'check_authentication',
#  'confimport',
#  'do_request',
#  'id',
#  'login',
#  'session',
#  'timeout',
#  'url',
#  'use_authenticate']

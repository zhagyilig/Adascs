# %%
import json
import gitlab

conf_info = '/Users/mac/.config/py_conf/conf'

# 加载配置文件,获取 gitlab api 认证
try:
    with open(conf_info, 'r') as f:
        results = json.load(f)
        url = results['gitlab']['url']
        token = results['gitlab']['token']
except FileNotFoundError as e:
    print('No such file or directory: %s' % conf_info)


gl = gitlab.Gitlab(url, token)

# pro_page = gl.projects.list()  # 获取第一页projects
# print(pro_page)

# pro_all = gl.projects.list(all=True) # 获取所有的项目
# print(pro_all)
# print(len(pro_all))


pro_list = []
for p in gl.projects.list(all=True, as_list=False):
    pro_name = p.name
#     print(pro_name) 
    pro_list.append(pro_name)
print(len(pro_list))


# 查找项目
pro_search = gl.projects.list(search='zuul')
print(pro_search)
# Out:
# apidoc
# blazer-order
# blazer-redis
# blazer-zuul
# blazer-account
# blazer-user
# learn_git
# ezrpc
# Flutter
# UIKit
# uatlog
# blazer-config
# blazer-core
# megatron.65emall.net
# megatron.ezbuy.com
# blazer
# megatron
# mhsr
# ezPrice
# hi
# hello
# protobuf-gen
# pool
# m.alsdelivery.com
# mhsr
# letmegrpc
# puppet
# robo
# page
# lme-doc
# DbDoc
# ezrpc
# lme-doc
# lme-doc
# lme
# doc
# karbi
# ops-config
# testing
# edm
# weekly-problem
# weekly-work
# wiki
# opendoc
# ob
# mssql-terminator
# openapi
# EZDB
# detalase-release
# DbDoc
# blind
# detalase-doc
# performance
# cs.uat
# cs.online
# cs
# dc-app
# dc-web
# dba
# dc
# BIReport
# private-project-xutianzhi
# egg-example
# otter
# shake
# MarketingTWC
# rosetta
# als-android-rpc
# billions
# mautic
# tonghelper
# hsr-web.uat
# ticketdemo
# hsr-web.online
# ezdelivery
# chsr
# lme
# apidoc
# albion
# ezOpen
# basis
# alsbiz-android
# detalase-config
# apidoc
# ezbuyapp_demo
# clover.online
# clover.65emall.net
# clover
# detalase
# oms
# tgrpc
# my-app
# oms-grpc-gateway
# detalase
# decorator-design-pattern
# observer-design-pattern
# heLearnGo
# foundation
# spring-starter
# ez-antd-react
# delivery
# type-test-project
# my-typescript-project
# ez-lodop
# Modu
# ez-lodop
# LodopDemo
# gunbuster
# express
# warehouse
# cmdb
# cmdb
# apidoc
# mirror
# station
# hsr.online
# hsr.65emall.net
# hsr
# customer
# iPhoneSG-note
# sample
# organization
# account
# sample
# account
# zmddemo11
# zmdtest1
# test2
# test
# zuul
# shadowaccount
# testWork
# core
# jedisque
# scheduler
# message
# sso
# order
# testgitlab
# m-tw.ezbuy.com
# configuration
# spkwiki
# try
# amalgam
# illidan
# ezbuyMobileRegister
# isaribi
# buddha
# rediset
# test1
# ezpack-dashboard
# gtm-tag-transfer
# ezAdminTransfer
# eltreum
# twadmin.ezbuy.com
# twadmin.65emall.net
# seller-merchants
# ezjs
# ez-editor
# ticket
# cdn-resources-checker
# goDemo
# pkadmin.ezbuy.com
# pkadmin.65emall.net
# ezmok
# pre-commit-go
# marketing-pk.ezbuy.com
# m-pk.ezbuy.com
# trace
# protoc-gen-json-ts
# dummy
# mobile-frame-files
# WebSocketDemoTest
# jumptool
# wechat-work
# deucalion
# titans-gen
# MysqlArchive
# ezmok
# minerProSite
# miner.65emall.net
# test-product
# css-grid
# react-quill-old-react16
# comment
# nilport
# cubi-demo
# find-antd-modules
# parcel_taste
# popup
# gohtml
# tights-rn
# test1
# admin
# translate
# miner
# binkit
# wautic
# paidan
# webImport
# gernsback
# fake-mobx
# search-checkbox
# postman
# load
# expresscn
# expresscn
# crow
# ezwiki
# umbrellacn
# ugm
# MyGo
# shadow
# oplogger
# simple-git
# eltreumsync
# anduin
# consul-sync
# ezgoogle
# share1
# EzbuyTest
# shied-share
# chaplin
# config_center
# moxiaobei
# sentry-uploader
# appcommon
# garencieres
# jedidoc
# pygoogleanalytics
# jedi
# docs
# EzbuyTest
# rfw_APITest
# rfw_UITest
# OnlineMonitor
# carttest
# 65Page-i18n
# recommend
# koreaseller.65emall.net
# ezbuyapp-bridge
# OnlineMonitor
# manual-autoorder
# screen-name-tracker
# gtm
# falke
# ezbuyfe-config
# tianyan
# app-bridge
# korea-seller
# korea-seller
# recommendation
# spkadmin
# tracker
# nadesico
# allautoorder
# ezbuyMobileRegister-landing
# EzbizReactNative
# EzbuyTest
# vwms
# ackreview
# simple-git
# titans-gen
# porter
# collect-uat
# collect
# scaffold
# ezpublish
# tyrande
# ezstatic
# dailychecker
# pigeon
# ezseller.ezbuy.com
# chest
# mytest
# PreMithril
# umbrella
# awesome
# ezPicBot
# ezDBSync
# advanced_alert_center
# ezseller.65emall.net
# eztools
# ezpack
# spknet
# usermsgcenter
# shield.ezbuy.sg
# hedwig
# paymentconv
# dbdoc
# gospm
# shield-uat
# shield
# ezPackage
# spktool
# autoorderService
# ezPTL
# pantos
# zhantang
# sting
# spk
# ezMail
# merchandiseToSeller
# yqhcallback
# alimama-highrebate-links
# activity
# api_test_try
# productServer
# carttest
# erpbot
# allautoRebate-release
# allautoRebate-origin
# ezbuyMobileWebUAT
# gauge_test
# arabian-nights-prod
# arabian-nights-uat
# arabian-nights-origin
# d2d-shipment-origin
# d2d-shipment
# alimama-uat
# alimama-deploy
# alimama
# tights-preview
# tights-prod-deploy
# bidynamicreport
# BIScripts
# freshdesktool
# cartsaver
# ezOrder
# ezStatus
# aspirin
# tong
# perftest
# test
# purchasecheck
# assassin
# Tights
# matrix
# findtext
# langs-util
# metamorphosis
# localezstatic
# veda
# freshdesk
# buzz
# mithril
# ezseller
# localdeliveryfee
# ezbuyWeb
# titans
# mqClient
# langs-loader
# mailservice
# redPacket
# eztest
# spiderscript
# getTest
# micro
# cart
# pushservice
# xdc
# xiemx
# autoorder
# gaugeProject
# grpc_rb_test
# gaugetest
# minerva
# dis
# protobufgen
# primewishlist
# gateway
# tsnewerp_uatdeploy
# tsnewerp_deploy
# fecommonlibs
# OrderTrack
# dragonfly
# doraemon
# taobaoapi
# TimeoutCompensation
# koreaseller.ezbuy.com
# 65Proxy
# flashsales
# newint2.ezbuy.sg
# oktights
# tsnewerp
# mytest
# go-qr-generator
# langresource
# uat
# biz
# apigw
# glan
# marketing.id.ezbuy.com
# marketing.ezbuy.co.th
# MarketingID
# MarketingTH
# vehicle
# m.ezbuy.co.id
# example
# express
# h.ezbuy.co.id
# flawtracker
# marketing
# express
# liyingtest
# chengjingjing_git_test
# lijing_study
# liying_test
# autoConfirmPay
# trans
# tborder
# m.ezbuy.co.th
# trans
# qing
# towercli
# TrendingShow
# gospider
# calcProductGmv
# ezsellerstatis
# ezsms
# m.id.65emall.net
# m.th.65emall.net
# m.my.65emall.net
# m.sg.65emall.net
# friendsDeal
# mobilewebbyts
# ezspidersearch
# ezSpider
# dayTowers
# web
# h.sg.65emall.net
# h.au.ezbuy.com
# primeHomepage
# love-donate
# wranglerservice
# UserCoinOperator
# goflow
# base
# vendor
# ezspiderjs
# prepay
# simpleregisterlogin
# h.id.ezbuy.com
# h.ezbuy.co.th
# h.ezbuy.my
# h.ezbuy.sg
# referral
# m.65emall.net
# googleanalytics
# webV3
# Statis
# adminBanner
# HiRebCrawl
# googleadwordsconversion
# UED
# android-ezbuy-rpc
# ezseller
# vouchersender
# googleadwords
# BIScripts
# usercoin
# appHomepage
# dbporter
# groupbuy
# scstats
# newDgadmin
# giftcard
# slotsadmin
# slots
# gallery
# h.au.65emall.net
# h.id.65emall.net
# h.th.65emall.net
# coinvoucherexadmin
# coinvoucherex
# gallery
# galleryadmin
# favourite
# d2d
# CustomWinFormApp
# erp-refactor-deploy
# erp-refactor-uat
# skeleton
# ding
# erp-refactor
# erpnew
# d2dAdmin_bak
# userset
# lib
# awesome
# ezchoose
# TrendingShow
# tableau
# ezspider-alimama
# rpcsiege
# myjoin
# featurecollection
# job
# test_tools
# ceqdl
# ezbuy.com
# popupAdmin
# voucherAdmin
# champagne
# admindoc
# cachedoc
# samsara
# sweepQRcode
# git_testing
# m.65daigou.com
# i18n
# ezspider-search
# slotmachine
# 5yeargame
# rpcdoc
# test
# merchandiseToSeller_deploy
# apitest_old
# AutoTest_UI
# webhook-server
# m.ezbuy.my
# delivery
# daydayup
# study_20160422
# TEST1
# parcelforce
# sssspidar
# ezspider
# mobilewebforapp
# Qarth
# mobileweb
# merchandiseToSeller_deployuat
# ezbuyMobileRegister
# merchandiseToSeller
# MarketingRegister
# contactsync
# 65Tool_SRC
# ezspider-shipfee
# autobuyplugin
# idcm
# tmallspider
# WebpackSeedProject
# account
# h.65daigou.com.my
# m.ezbuy.sg
# 65mobile_deploy
# h.my.ezbuy.com
# MarketingAU
# MarketingMY
# MarketingSG
# appDownload
# h.my.65emall.net
# ezbuyHomeLink
# go-devwatcher
# 65daigou.com
# ezspider_shopId
# AutoTest
# DesignHouse
# abtest
# home-release
# admin.65daigou.com
# webpack-homepagArrange
# MiscScripts
# 65dgAdmin
# ActivityPacket
# categoryTemplate
# bulma-front
# bulma
# dgadmin
# mobileSeedProject
# goget
# RedPacket
# h.65daigou.com
# ezspider
# core
# ezbuy_Year_landing_page
# m.id.ezbuy.com
# test
# mid.65emall.net
# m.65daigou.my
# AccountTool
# newhome-go
# 65marketing-my-gen
# spike
# webhooktest
# mmy.65emall.net
# mapp.65emall.net
# m.ezbuy.au
# webapi.65daigou.com
# TRPC
# 65Page
# mobileweb-dist-au
# ezstatic
# 65marketing-au
# report.65daigou.com
# ezcartplugin
# marketingHome-AU
# aoe
# ezcartplugin-server
# static.65emall.net
# 65daigoustaticdeploy
# buywith65daigou
# partnershipGenerator
# PDT
# ezbiz
# marketing
# selfCollectionSys
# parcel.65daigou.com
# Wrangler
# reactmediumeditor
# ezdata
# ShareDocuments
# systemmangement
# mobileweb-dist
# wiki
# ios
# techwiki
# bps.65emall.com
# www.65emall.com
# ReddotPayment
# iPhoneSG
# d2d_client
# d2d_web
# taobaofilter
# ezcrawler
# ezlookup
# dept_msg
# Coat
# 65surf
# ezbuy.com
# env.65daigou.com
# erp.ezbuy.com
# featureCollectionRemove
# featreCollectionExcelImporter
# int.65daigou.com
# Wrangler_backup
# log.65daigou.com
# common.65daigou.com
# wholesale.65daigou.com
# schedule.65daigou.com
# mobilewebold
# EZBuy_ADP
# PDT_SG
# iPhoneMY
# DPS.ezbuy
# ac.65daigou.com
# DaogouAdmin
# iPhoneSG
# Android.SG
# FeatureCollectionTool
# www.65daigou.com
# DPS.MY
# DPS.SG
# 653
